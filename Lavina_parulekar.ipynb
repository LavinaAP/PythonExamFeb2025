# %%
#Q1 printing missing characters to form a pangram

def missing_charater():
    alpha = "abcdefghijklmnopqrstuvwxyz"
    
    str1 = "The quick brown fox jumps over the lazy dog"
    str2 = str1.lower()  
    
    missing_ch =[]
    
    to_chcek_pangram = "The quick brown fox Jumps over the"
    str4 = to_chcek_pangram.lower()
    
  if len(set(str2)==len(alpha)): 
    for i in str4:
        if   str4 in str2 :
            return print("string is already pangram")
        else:
            l1 = sorted(list(str2).strip(" "))
            l2 = sorted(list(str4).strip(" "))
            for i in range(len(l1)):
                for j in range(len(l2)):
                  if l1[i] !=l2[j]:
                      missing_ch.append(l2[j])

            print(sorted(missing_ch))
            
            return print("string is not pangram due to this character:",missing_ch)
            
missing_charater()

# %%
#Q2 inventory management system

def inventory_management():
    print("Inventory management sytem")
    count = int(input("Enter the number of products you want to add:"))
    d = {}
    for i in range(count):
        prod_id = int(input("Enter the product id:"))    
        prod_name = input("Enter the product name:")
        catogory = input("Enter the catogory name:")
        price = int(input("Enter the product name:"))
        Quantity = int(input("Enter the product name:"))
    
        d[prod_id]
        {
           "prod_name" : prod_name,
            "catogory" : catogory,
            "price": price,
            "Quantity" : Quantity,         
        }
        print(d)
while True:
    print("Inventory management sytem")
    choice = int(input("Enter your choice:"))
    print("----------------------------")
    print("1.data parsing")
    print("2.data validation")
    print("3.sales revenue calculation")
    print("4.report generation")
     print("0.Exit")
    print("----------------------------")

    if choice == 0:
        print("Exit...")
    elif choice == 1:
        print(d)
    elif choice == 2:
        print("2.data validation")
        print(d[prod_id]["Quantity"])
        print(d[prod_id]["Price"])
        if d[prod_id]["Price"] >0:
            print("Prices are validated and are greater than 0")
        else:
            print("prices are not greater than 0")
            
       
    elif choice == 3:
            print("sales revenue calculation")

    elif choice == 4:
        print("Generating the report....")
        print(d[prod_id]["prod_name"])
        print(d[prod_id]["catogory"])    
        
    
inventory_management()
